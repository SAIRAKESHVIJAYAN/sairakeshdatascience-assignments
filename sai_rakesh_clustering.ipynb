# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-fb825bdc-8792-4428-8e59-0fbccf41eb1c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-fb825bdc-8792-4428-8e59-0fbccf41eb1c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
df = pd.read_excel('EastWestAirlines.xlsx')

# %%
print(df.isnull().sum())
# Out:
# East-West Airlines is trying to learn more about its customers.  Key issues are their     8
# Unnamed: 1                                                                               13
# Unnamed: 2                                                                               20
# Unnamed: 3                                                                               13
# Unnamed: 4                                                                                8
# dtype: int64

# %%
import pandas as pd
df = pd.read_excel('EastWestAirlines.xlsx')
print(df.dtypes)
numeric_cols = df.select_dtypes(include=['number']).columns
df
# Out:
# East-West Airlines is trying to learn more about its customers.  Key issues are their    object
# Unnamed: 1                                                                               object
# Unnamed: 2                                                                               object
# Unnamed: 3                                                                               object
# Unnamed: 4                                                                               object
# dtype: object
#    East-West Airlines is trying to learn more about its customers.  Key issues are their  \
# 0   flying patterns, earning and use of frequent f...
# 1   card.  The task is to identify customer segmen...
# 2                                                 NaN
# 3                                                 NaN
# 4   Source: Based upon real business data; company...
# 5              (c) 2016 Galit Shmueli and Peter Bruce
# 6                                                 NaN
# ...

# %%
import pandas as pd
from scipy import stats
import numpy as np


df = pd.read_excel('EastWestAirlines.xlsx')

numeric_cols = df.select_dtypes(include=['number']).columns
df_numeric = df[numeric_cols]

df_filtered = df_numeric[(np.abs(stats.zscore(df_numeric)) < 3).all(axis=1)]

df_final = pd.merge(df_filtered, df.drop(columns=numeric_cols), left_index=True, right_index=True)

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
df = pd.read_excel('EastWestAirlines.xlsx')


numeric_features = df.select_dtypes(include=['number']).columns
df_numeric = df[numeric_features]
if len(numeric_features) > 0:
    scaler = StandardScaler()
    scaled_data = scaler.fit_transform(df_numeric)

    df_scaled = pd.DataFrame(scaled_data, columns=numeric_features, index=df.index)

    df_final = pd.concat([df_scaled, df.drop(columns=numeric_features)], axis=1)

else:
    print("No numeric features found in the DataFrame.")
# Out:
# No numeric features found in the DataFrame.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_excel('EastWestAirlines.xlsx')

print(df.dtypes)


numeric_cols = df.select_dtypes(include=['number']).columns

if len(numeric_cols) > 0:
        df[numeric_cols].hist(bins=30, figsize=(12, 10))
    plt.tight_layout()
    plt.show()

    sns.pairplot(df[numeric_cols])
    plt.show()
else:
    print("No numeric features found in the DataFrame.")
# Out:
# East-West Airlines is trying to learn more about its customers.  Key issues are their    object
# Unnamed: 1                                                                               object
# Unnamed: 2                                                                               object
# Unnamed: 3                                                                               object
# Unnamed: 4                                                                               object
# dtype: object
# No numeric features found in the DataFrame.

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

df = pd.read_excel('EastWestAirlines.xlsx')

numeric_cols = df.select_dtypes(include=['number']).columns
df_numeric = df[numeric_cols]

if df_numeric.empty or df_numeric.isnull().all().all():
    print("No valid numeric data for correlation calculation.")
else:
        corr_matrix = df_numeric.corr()

    plt.figure(figsize=(10, 8))
    sns.heatmap(corr_matrix, annot=True, cmap='coolwarm', fmt='.2f')
    plt.title('Correlation Matrix')
    plt.show()
# Out:
# No valid numeric data for correlation calculation.

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt

df = pd.read_excel('EastWestAirlines.xlsx')

df_numeric = df[numeric_features]

if len(numeric_features) > 0:
    scaler = StandardScaler()
    scaled_data = scaler.fit_transform(df_numeric)
else:
    print("No numeric features found in the DataFrame.")
    scaled_data = None
inertia = []
k_values = range(1, 11)

if scaled_data is not None:
      for k in k_values:
        kmeans = KMeans(n_clusters=k, random_state=42)
        kmeans.fit(scaled_data)
        inertia.append(kmeans.inertia_)

    plt.figure(figsize=(8, 5))
    plt.plot(k_values, inertia, marker='o')
    plt.title('Elbow Method for Optimal K')
    plt.xlabel('Number of Clusters (K)')
    plt.ylabel('Inertia')
    plt.grid()
    plt.show()

    optimal_k = 3
    kmeans = KMeans(n_clusters=optimal_k, random_state=42)
    kmeans_labels = kmeans.fit_predict(scaled_data)

    plt.scatter(scaled_data[:, 0], scaled_data[:, 1], c=kmeans_labels, cmap='viridis')
    plt.title('K-Means Clustering Results')
    plt.xlabel('Feature 1')
    plt.ylabel('Feature 2')
    plt.show()
else:
    print("Cannot perform KMeans clustering as scaled_data is not defined.")
# Out:
# No numeric features found in the DataFrame.
# Cannot perform KMeans clustering as scaled_data is not defined.

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import matplotlib.pyplot as plt
from scipy.cluster.hierarchy import dendrogram, linkage
from sklearn.cluster import AgglomerativeClustering

df = pd.read_excel('EastWestAirlines.xlsx')
numeric_features = df.select_dtypes(include=['number']).columns
df_numeric = df[numeric_features]

if len(numeric_features) > 0:
    scaler = StandardScaler()
    scaled_data = scaler.fit_transform(df_numeric) # Define scaled_data here
else:
    print("No numeric features found in the DataFrame.")
    scaled_data = None

inertia = []
k_values = range(1, 11)

if scaled_data is not None:
      for k in k_values:
        kmeans = KMeans
# Out:
# No numeric features found in the DataFrame.

# %%
numeric_features = df.select_dtypes(include=['number']).columns
df_numeric = df[numeric_features]

if len(numeric_features) > 0:
     scaler = StandardScaler()
     scaled_data = scaler.fit_transform(df_numeric)
else:
    print("No numeric features found in the DataFrame.")
    scaled_data = None
# Out:
# No numeric features found in the DataFrame.

# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
from sklearn.metrics import silhouette_score

df = pd.read_excel('EastWestAirlines.xlsx')


numeric_features = df.select_dtypes(include=['number']).drop(columns=['ID#'], errors='ignore').columns
df_numeric = df[numeric_features]


if len(numeric_features) > 0:
    scaler = StandardScaler()
    scaled_data = scaler.fit_transform(df_numeric)
else:
    print("No numeric features found in the DataFrame.")
    scaled_data = None

if scaled_data is not None:
  optimal_k = 3
  kmeans
# Out:
# No numeric features found in the DataFrame.
